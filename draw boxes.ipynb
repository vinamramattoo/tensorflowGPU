# %%
import sys
sys.path.append('/home/vinamra/anaconda3/envs/tgpu/lib/python3.6/site-packages/')

# %%
import cv2
import pandas as pd
from PIL import Image

# %%
full_labels = pd.read_csv('data/raccoon_labels.csv')

# %%
full_labels.head()
# Out:
#           filename  width  height    class  xmin  ymin  xmax  ymax
# 0    raccoon-1.jpg    650     417  raccoon    81    88   522   408
# 1   raccoon-10.jpg    450     495  raccoon   130     2   446   488
# 2  raccoon-100.jpg    960     576  raccoon   548    10   954   520
# 3  raccoon-101.jpg    640     426  raccoon    86    53   400   356
# 4  raccoon-102.jpg    259     194  raccoon     1     1   118   152

# %%
def draw_boxes(image_name):
    selected_value = full_labels[full_labels.filename == image_name]
    img = cv2.imread('images/{}'.format(image_name))
    for index, row in selected_value.iterrows():
        img = cv2.rectangle(img, (row['xmin'], row['ymin']), (row['xmax'], row['ymax']), (0, 255, 0), 3)
    return img

# %%
Image.fromarray(draw_boxes('raccoon-1.jpg'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-85cfba7646d9> in <module>()
# ----> 1 Image.fromarray(draw_boxes('raccoon-1.jpg'))
#
# <ipython-input-6-63ea7bd78d09> in draw_boxes(image_name)
#       1 def draw_boxes(image_name):
#       2     selected_value = full_labels[full_labels.filename == image_name]
# ----> 3     img = cv2.imread('images/{}'.format(image_name))
#       4     for index, row in selected_value.iterrows():
#       5         img = cv2.rectangle(img, (row['xmin'], row['ymin']), (row['xmax'], row['ymax']), (0, 255, 0), 3)
#
# AttributeError: module 'cv2' has no attribute 'imread'

# %%
Image.fromarray(draw_boxes('raccoon-50.jpg'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-5dcd4686db02> in <module>()
# ----> 1 Image.fromarray(draw_boxes('raccoon-50.jpg'))
#
# <ipython-input-6-63ea7bd78d09> in draw_boxes(image_name)
#       1 def draw_boxes(image_name):
#       2     selected_value = full_labels[full_labels.filename == image_name]
# ----> 3     img = cv2.imread('images/{}'.format(image_name))
#       4     for index, row in selected_value.iterrows():
#       5         img = cv2.rectangle(img, (row['xmin'], row['ymin']), (row['xmax'], row['ymax']), (0, 255, 0), 3)
#
# AttributeError: module 'cv2' has no attribute 'imread'

# %%
Image.fromarray(draw_boxes('raccoon-150.jpg'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-8fa9d58e2c3c> in <module>()
# ----> 1 Image.fromarray(draw_boxes('raccoon-150.jpg'))
#
# <ipython-input-6-63ea7bd78d09> in draw_boxes(image_name)
#       1 def draw_boxes(image_name):
#       2     selected_value = full_labels[full_labels.filename == image_name]
# ----> 3     img = cv2.imread('images/{}'.format(image_name))
#       4     for index, row in selected_value.iterrows():
#       5         img = cv2.rectangle(img, (row['xmin'], row['ymin']), (row['xmax'], row['ymax']), (0, 255, 0), 3)
#
# AttributeError: module 'cv2' has no attribute 'imread'

# %%
Image.fromarray(draw_boxes('raccoon-200.jpg'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-5a2599addfed> in <module>()
# ----> 1 Image.fromarray(draw_boxes('raccoon-200.jpg'))
#
# <ipython-input-6-63ea7bd78d09> in draw_boxes(image_name)
#       1 def draw_boxes(image_name):
#       2     selected_value = full_labels[full_labels.filename == image_name]
# ----> 3     img = cv2.imread('images/{}'.format(image_name))
#       4     for index, row in selected_value.iterrows():
#       5         img = cv2.rectangle(img, (row['xmin'], row['ymin']), (row['xmax'], row['ymax']), (0, 255, 0), 3)
#
# AttributeError: module 'cv2' has no attribute 'imread'

# %%
Image.fromarray(draw_boxes('raccoon-18.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=240x156 at 0x10C803400>

# %%
Image.fromarray(draw_boxes('raccoon-40.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=480x360 at 0x10C8034A8>

# %%
Image.fromarray(draw_boxes('raccoon-2.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=800x573 at 0x105A86128>

# %%
Image.fromarray(draw_boxes('raccoon-22.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=640x360 at 0x10C803940>
